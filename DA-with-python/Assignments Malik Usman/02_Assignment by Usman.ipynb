# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
#BONUS CALCULATOR
sal = int(input("Enter salary of Employee: "))
yrs = int(input("Enter service years in company : "))

if yrs > 5:
    bonus = sal * 5 / 100
    print("Bonus Awand to Employees having Service More than 5 Years:", bonus)
else:
    print("For Bonus, Your Service must be more than 5 Years, Keep Hard Working")
# Out:
# Bonus Awand to Employees having Service More than 5 Years: 3000.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
# Eligible for Voting
age = int(input("Enter the age of Person: "))


if age > 17:
    print(f"Your age is {age} Years, Eligible for Voting")
else:
    print(f"Your age is {age} Years, Under 18 Not Eligible for Voting")
# Out:
# Your age is 21 Years, Eligible for Voting

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
# ODD and Even Number Cheaker

num = int(input("Enter any number:"))

if num % 2 == 0:
    print(f"You Enter Number {num}, which is EVEN")
else:
    print(f"You Enter Number {num}, which is ODD")
# Out:
# You Enter Number 73, which is ODD

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
# 7 Divisible
num = int(input("Enter any number:"))

if num % 7 == 0:
    print(f"You Enter Number: {num}, which is Divisible by 7 ")
else:
    print(f"You Enter Number: {num}, which is not Divisible by 7")
# Out:
# You Enter Number: 5896, which is not Divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
#Number ChecKer
num = int(input("Enter any number:"))

if num % 5 == 0:
    print(f"You Enter Number: {num}, which is Multiple of 5 ")
else:
    print(f"You Enter Number: {num}, which is Multiple of 5 ")
# Out:
# You Enter Number: 62570, which is Multiple of 5

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
#Find last digit of a number
numb = int(input("Enter any number: "))

dig = numb % 10

print(f"You enterd number {numb}, Last Digit of Your Number is :", dig)
# Out:
# You enterd number 2546, Last Digit of Your Number is : 6

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
#ChecK Square and Rectangle 

len = int(input("Enter the Lenght of Shape: "))

brth = int(input("Enter the breaht of Shape:"))

if len == brth:
    print("The Shape is Square")
else:
    print("The Shape is Rectanle")
# Out:
# The Shape is Rectanle

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
# Greatest Value

val1 = int(input("Enter the First Value: "))

val2 = int(input("Enter the Second Value: "))

if val1 > val2:
    print(f" Values {val1} are Greatest than {val2} ")

elif val1<val2:
    print(f" Values {val2} are Greatest than {val1} ")
else:
    print(f"Both Values {val1} and {val2} are Equal")
# Out:
#  Values 23 are Greatest than 12

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
#Judge the Cost of Purchased Quantity 

qty = int(input("Enter Purchased Quantity: "))

tot = qty * 100

if tot > 1000:
    disc = tot * 10 / 100
    disc_amt = tot - disc
    print("Discount Amount are:", disc)
    print("Total Cost of Quantities:", disc_amt)
else:
    disc = 0
    print("Discount Amount are:", disc)
    print("Total Cost of Quantities:", tot)
# Out:
# Discount Amount are: 180.0
# Total Cost of Quantities: 1620.0

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
# a. Below 25 - F
# b. 25 to 45 - E
# c. 45 to 50 - D
# d. 50 to 60 - C
# e. 60 to 80 - B
# f. Above 80 - A

grd = int(input("Enter Your Grade"))

if grd < 25: 
    print("You obtainded Grade:  F ")

elif grd >= 25 and grd < 45: 
    print("You obtainded Grade:  E") 

elif grd >= 45 and grd < 50: 
    print("You obtainded Grade:  D") 

elif grd>= 50 and grd < 60: 
    print("You obtainded Grade:  C")

elif grd >= 60 and grd <= 80: 
    print("You obtainded Grade:  B")
    
else:
    print("You obtainded Grade:  A")
# Out:
# You obtainded Grade:  A

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
#Attedence Calculator

tot_class= int(input("Enter total number of classes held uptill now : "))
pre_class = int(input("Enter you total number of presents in class: "))



perc = (pre_class / tot_class) * 100

print("Student Attendance Percentage are:", perc)

if perc >= 75:
    print("Student is allowed to sit in Exam")
else:
    print("Student is not allowed to sit in Exam")
# Out:
# Student Attendance Percentage are: 87.5
# Student is allowed to sit in Exam

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
#Attedence Calculator with Medical

tot_class= int(input("Enter total number of classes held uptill now : "))
pre_class = int(input("Enter total number of your presents in class: "))
medical = input("Do You have any Medical Cause during Classes, Entered : Y / N ")



perc = (pre_class / tot_class) * 100

print("Student Attendance Percentage are:", perc)

if perc >= 75:
    print("Student is allowed to sit in Exam")
elif perc <= 75 and medical == "Y":
    print("Due to Medical Cause, Student is allowed to sit in Exam")
else:
    print("Student is not allowed to sit in Exam")
# Out:
# Student Attendance Percentage are: 44.44444444444444
# Due to Medical Cause, Student is allowed to sit in Exam

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
#Leap Years
u_year= int(input("Enter the Year : "))

if u_year % 4 == 0:
    print(f"The Year entered by User {u_year}, is Leap year")
else:    
    print(f"The Year entered by User {u_year}, is Leap year")
# Out:
# The Year entered by User 2026, is Leap year

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
#Type your code here

age = int(input("Enter the age Employee: "))
gender = input("Enter the gender Employee (Male/Female): ")
marital = input("Enter marital status, are you married (Y/N): ")

gender = gender.upper()
if gender == "FEMALE":
    print("FEMALE Employee will work only in urban areas")

elif gender == "MALE" and age >= 20 and age <= 40:
    print("MALE Employee may work anywhere")

elif gender == "MALE" and age > 40 and age <= 60:
    print("MALE Employee will work only in urban areas")

else:
    print("SORRY YOU CANN'T FILL COMPANY POLICY")
# Out:
# FEMALE Employee will work only in urban areas

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %%
#Electricity Bill Calculator

units = int(input("Enter electricity bill units: ")) 

unit_100 = units
unit_300 = units - 100
unit_abv300 = units - 300

if units <= 100:
 print("Your Total unit consumed are : ", unit_100)
 bill = 0 

elif units <= 300: 
   print("Your Total unit consumed are : ", unit_300)
   bill = unit_300 * 5 

else: 
   print("Your Total unit consumed are :", units)
   bill = (unit_300 * 5) + (unit_abv300 * 10)  

print("Your Total electricity bill are : Rs.", bill)
# Out:
# Your Total unit consumed are : 354
# Your Total electricity bill are : Rs. 1810

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
#Determine Oldest and Youngest

p1 = int(input("Enter age of first person : "))
p2 = int(input("Enter age of second person : "))
p3 = int(input("Enter age of third person: "))



#oldest

if p1 >= p2 and p1 >= p3:
    oldest = p1

elif p2 >= p1 and p2 >= p3:
    oldest = p2

else:
    oldest = p3

#eldest

if p1 <= p2 and p1 <= p3:
    youngest = p1

elif p2 <= p1 and p2 <= p3:
    youngest = p2

else:
    youngest = p3


if p1 == p2 and p2 == p3:
    print("All three person have the same age")
else:
    print("Oldest Person age is:", oldest)
    print("Youngest Person age is:", youngest)
# Out:
# Oldest Person age is: 85
# Youngest Person age is: 50
